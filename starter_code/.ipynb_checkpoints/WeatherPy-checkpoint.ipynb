# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

city_name = []
new_cities = []
country = []
latitude = []
longitude = []
date = []
temp = []
temp_max = []
humidity = []
cloudiness = []
wind_speed = []

record_count = 0
sets_count =  0
record = []
sets = []

print(f"Beginning Data Retrieval")
print(f"-----------------------------")

for city in cities:
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    response = requests.get(query_url + city).json()
    if record_count < 50:
        record_count = record_count+1
    else:
        sets_count = sets_count+1
        record_count = 0
    print('Processing record {} of set {} | {}'.format(record_count, sets_count, city))

    
    try:
        city_name.append(response['name'])
        new_cities.append(city)
        country.append(response['sys']['country'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        date.append(response['dt'])
        temp.append(response['main']['temp'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])       
        wind_speed.append(response['wind']['speed'])
        
        
    except KeyError:
        print(f"City not found...")
        pass
    
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record 1 of set 0 | plettenberg bay
# Processing record 2 of set 0 | ponta do sol
# Processing record 3 of set 0 | new norfolk
# Processing record 4 of set 0 | vaini
# Processing record 5 of set 0 | punta arenas
# Processing record 6 of set 0 | singaraja
# Processing record 7 of set 0 | east london
# Processing record 8 of set 0 | ribeira grande
# Processing record 9 of set 0 | porto belo
# Processing record 10 of set 0 | gornyy
# Processing record 11 of set 0 | pevek
# Processing record 12 of set 0 | rikitea
# Processing record 13 of set 0 | nikolskoye
# Processing record 14 of set 0 | gisborne
# Processing record 15 of set 0 | hamilton
# Processing record 16 of set 0 | touros
# Processing record 17 of set 0 | taolanaro
# City not found...
# Processing record 18 of set 0 | jamestown
# Processing record 19 of set 0 | ganzhou
# Processing record 20 of set 0 | amderma
# City not found...
# Processing record 21 of set 0 | hvittingfoss
# Processing record 22 of set 0 | cidreira
# Processing record 23 of set 0 | kapaa
# Processing record 24 of set 0 | mindelo
# Processing record 25 of set 0 | thompson
# Processing record 26 of set 0 | sao miguel
# Processing record 27 of set 0 | puerto baquerizo moreno
# Processing record 28 of set 0 | kongolo
# Processing record 29 of set 0 | souillac
# Processing record 30 of set 0 | abrau-dyurso
# Processing record 31 of set 0 | upernavik
# Processing record 32 of set 0 | port elizabeth
# Processing record 33 of set 0 | itaqui
# Processing record 34 of set 0 | qasigiannguit
# Processing record 35 of set 0 | nanortalik
# Processing record 36 of set 0 | mys shmidta
# City not found...
# Processing record 37 of set 0 | avarua
# Processing record 38 of set 0 | tiksi
# Processing record 39 of set 0 | labuan
# Processing record 40 of set 0 | mataura
# Processing record 41 of set 0 | south yuba city
# Processing record 42 of set 0 | klaksvik
# Processing record 43 of set 0 | kempsey
# Processing record 44 of set 0 | yellowknife
# Processing record 45 of set 0 | provideniya
# Processing record 46 of set 0 | namibe
# Processing record 47 of set 0 | maniitsoq
# Processing record 48 of set 0 | saleaula
# City not found...
# Processing record 49 of set 0 | tiszakarad
# Processing record 50 of set 0 | port alfred
# Processing record 0 of set 1 | ushuaia
# Processing record 1 of set 1 | kaitangata
# Processing record 2 of set 1 | busselton
# Processing record 3 of set 1 | guadalupe y calvo
# Processing record 4 of set 1 | atuona
# Processing record 5 of set 1 | albany
# Processing record 6 of set 1 | mahajanga
# Processing record 7 of set 1 | mount isa
# Processing record 8 of set 1 | suhbaatar
# Processing record 9 of set 1 | kristiansund
# Processing record 10 of set 1 | hermanus
# Processing record 11 of set 1 | coahuayana
# Processing record 12 of set 1 | luau
# Processing record 13 of set 1 | batagay-alyta
# Processing record 14 of set 1 | sorland
# Processing record 15 of set 1 | hithadhoo
# Processing record 16 of set 1 | makakilo city
# Processing record 17 of set 1 | sharlyk
# Processing record 18 of set 1 | sur
# Processing record 19 of set 1 | bud
# Processing record 20 of set 1 | affery
# Processing record 21 of set 1 | longyearbyen
# Processing record 22 of set 1 | cape town
# Processing record 23 of set 1 | puerto ayora
# Processing record 24 of set 1 | narsaq
# Processing record 25 of set 1 | constitucion
# Processing record 26 of set 1 | conde
# Processing record 27 of set 1 | khatanga
# Processing record 28 of set 1 | bredasdorp
# Processing record 29 of set 1 | cabo san lucas
# Processing record 30 of set 1 | starobaltachevo
# Processing record 31 of set 1 | meulaboh
# Processing record 32 of set 1 | victoria
# Processing record 33 of set 1 | saint-philippe
# Processing record 34 of set 1 | hobart
# Processing record 35 of set 1 | banapur
# Processing record 36 of set 1 | tuatapere
# Processing record 37 of set 1 | marquette
# Processing record 38 of set 1 | bayan
# Processing record 39 of set 1 | matagami
# Processing record 40 of set 1 | leningradskiy
# Processing record 41 of set 1 | nioro
# Processing record 42 of set 1 | tuktoyaktuk
# Processing record 43 of set 1 | ancud
# Processing record 44 of set 1 | lagoa
# Processing record 45 of set 1 | san carlos
# Processing record 46 of set 1 | murygino
# Processing record 47 of set 1 | turukhansk
# Processing record 48 of set 1 | xai-xai
# Processing record 49 of set 1 | garden city
# Processing record 50 of set 1 | torbay
# Processing record 0 of set 2 | kungsbacka
# Processing record 1 of set 2 | kodiak
# Processing record 2 of set 2 | bubaque
# Processing record 3 of set 2 | coquimbo
# Processing record 4 of set 2 | chokurdakh
# Processing record 5 of set 2 | salvador
# Processing record 6 of set 2 | kahului
# Processing record 7 of set 2 | roald
# Processing record 8 of set 2 | kruisfontein
# Processing record 9 of set 2 | kattivakkam
# Processing record 10 of set 2 | port blair
# Processing record 11 of set 2 | one hundred mile house
# City not found...
# Processing record 12 of set 2 | forbes
# Processing record 13 of set 2 | qaanaaq
# Processing record 14 of set 2 | vargem grande
# Processing record 15 of set 2 | cherskiy
# Processing record 16 of set 2 | sungurlu
# Processing record 17 of set 2 | kondinskoye
# Processing record 18 of set 2 | samusu
# City not found...
# Processing record 19 of set 2 | el paso
# Processing record 20 of set 2 | jalu
# Processing record 21 of set 2 | vestmannaeyjar
# Processing record 22 of set 2 | chunskiy
# Processing record 23 of set 2 | kuzovatovo
# Processing record 24 of set 2 | mareeba
# Processing record 25 of set 2 | lazaro cardenas
# Processing record 26 of set 2 | saint-augustin
# Processing record 27 of set 2 | vila velha
# Processing record 28 of set 2 | vysokogornyy
# Processing record 29 of set 2 | karamay
# City not found...
# Processing record 30 of set 2 | scarborough
# Processing record 31 of set 2 | chuy
# Processing record 32 of set 2 | acateno
# City not found...
# Processing record 33 of set 2 | cleveland
# Processing record 34 of set 2 | necochea
# Processing record 35 of set 2 | port augusta
# Processing record 36 of set 2 | bambous virieux
# Processing record 37 of set 2 | tilichiki
# Processing record 38 of set 2 | butaritari
# Processing record 39 of set 2 | rosarito
# Processing record 40 of set 2 | fortuna
# Processing record 41 of set 2 | mar del plata
# Processing record 42 of set 2 | bodden town
# Processing record 43 of set 2 | itirucu
# Processing record 44 of set 2 | lompoc
# Processing record 45 of set 2 | paracuru
# Processing record 46 of set 2 | georgetown
# Processing record 47 of set 2 | kieta
# Processing record 48 of set 2 | katsuura
# Processing record 49 of set 2 | amapa
# Processing record 50 of set 2 | ijaki
# City not found...
# Processing record 0 of set 3 | vostok
# Processing record 1 of set 3 | tsihombe
# City not found...
# Processing record 2 of set 3 | barentsburg
# City not found...
# Processing record 3 of set 3 | beruwala
# Processing record 4 of set 3 | srednekolymsk
# Processing record 5 of set 3 | husavik
# Processing record 6 of set 3 | asau
# Processing record 7 of set 3 | hokitika
# Processing record 8 of set 3 | belushya guba
# City not found...
# Processing record 9 of set 3 | kailua
# Processing record 10 of set 3 | acapulco
# Processing record 11 of set 3 | angoche
# Processing record 12 of set 3 | carnarvon
# Processing record 13 of set 3 | tabiauea
# City not found...
# Processing record 14 of set 3 | faya
# Processing record 15 of set 3 | rio gallegos
# Processing record 16 of set 3 | san patricio
# Processing record 17 of set 3 | saint anthony
# Processing record 18 of set 3 | parczew
# Processing record 19 of set 3 | talara
# Processing record 20 of set 3 | shiki
# Processing record 21 of set 3 | sampit
# Processing record 22 of set 3 | tasiilaq
# Processing record 23 of set 3 | clonakilty
# Processing record 24 of set 3 | poddorye
# Processing record 25 of set 3 | esfarayen
# Processing record 26 of set 3 | iqaluit
# Processing record 27 of set 3 | karamea
# City not found...
# Processing record 28 of set 3 | ihosy
# Processing record 29 of set 3 | paamiut
# Processing record 30 of set 3 | manhumirim
# Processing record 31 of set 3 | codrington
# Processing record 32 of set 3 | tura
# Processing record 33 of set 3 | naze
# Processing record 34 of set 3 | matara
# Processing record 35 of set 3 | illoqqortoormiut
# City not found...
# Processing record 36 of set 3 | lorengau
# Processing record 37 of set 3 | barrow
# Processing record 38 of set 3 | encarnacion
# Processing record 39 of set 3 | sentyabrskiy
# City not found...
# Processing record 40 of set 3 | bathsheba
# Processing record 41 of set 3 | chara
# Processing record 42 of set 3 | hofn
# Processing record 43 of set 3 | beidao
# Processing record 44 of set 3 | dunedin
# Processing record 45 of set 3 | banda aceh
# Processing record 46 of set 3 | ozgon
# City not found...
# Processing record 47 of set 3 | port lincoln
# Processing record 48 of set 3 | solnechnyy
# Processing record 49 of set 3 | galveston
# Processing record 50 of set 3 | arraial do cabo
# Processing record 0 of set 4 | bobcaygeon
# Processing record 1 of set 4 | progreso
# Processing record 2 of set 4 | batagay
# Processing record 3 of set 4 | port hardy
# Processing record 4 of set 4 | gat
# Processing record 5 of set 4 | dabola
# Processing record 6 of set 4 | tharad
# Processing record 7 of set 4 | beringovskiy
# Processing record 8 of set 4 | mehamn
# Processing record 9 of set 4 | bluff
# Processing record 10 of set 4 | dawson creek
# Processing record 11 of set 4 | arlit
# Processing record 12 of set 4 | severodvinsk
# Processing record 13 of set 4 | barkhan
# Processing record 14 of set 4 | alofi
# Processing record 15 of set 4 | calnic
# Processing record 16 of set 4 | la spezia
# Processing record 17 of set 4 | valparaiso
# Processing record 18 of set 4 | salalah
# Processing record 19 of set 4 | malanje
# Processing record 20 of set 4 | punta alta
# Processing record 21 of set 4 | smidovich
# Processing record 22 of set 4 | faanui
# Processing record 23 of set 4 | hasaki
# Processing record 24 of set 4 | nizhneyansk
# City not found...
# Processing record 25 of set 4 | sabla
# Processing record 26 of set 4 | brokopondo
# Processing record 27 of set 4 | hami
# Processing record 28 of set 4 | hilo
# Processing record 29 of set 4 | palabuhanratu
# City not found...
# Processing record 30 of set 4 | attawapiskat
# City not found...
# Processing record 31 of set 4 | mercedes
# Processing record 32 of set 4 | camacha
# Processing record 33 of set 4 | qaqortoq
# Processing record 34 of set 4 | the valley
# Processing record 35 of set 4 | saint-georges
# Processing record 36 of set 4 | karaul
# City not found...
# Processing record 37 of set 4 | medicine hat
# Processing record 38 of set 4 | liverpool
# Processing record 39 of set 4 | airai
# Processing record 40 of set 4 | castro
# Processing record 41 of set 4 | ushtobe
# Processing record 42 of set 4 | vaitupu
# City not found...
# Processing record 43 of set 4 | quatre cocos
# Processing record 44 of set 4 | kununurra
# Processing record 45 of set 4 | kudahuvadhoo
# Processing record 46 of set 4 | hvammstangi
# City not found...
# Processing record 47 of set 4 | sao joao da barra
# Processing record 48 of set 4 | jackson
# Processing record 49 of set 4 | itupiranga
# Processing record 50 of set 4 | rincon
# Processing record 0 of set 5 | nome
# Processing record 1 of set 5 | colac
# Processing record 2 of set 5 | moranbah
# Processing record 3 of set 5 | petropavlovsk-kamchatskiy
# Processing record 4 of set 5 | zmievka
# City not found...
# Processing record 5 of set 5 | otavalo
# Processing record 6 of set 5 | pozo colorado
# Processing record 7 of set 5 | ostrovnoy
# Processing record 8 of set 5 | mahebourg
# Processing record 9 of set 5 | pisco
# Processing record 10 of set 5 | soldotna
# Processing record 11 of set 5 | arroyo
# Processing record 12 of set 5 | flinders
# Processing record 13 of set 5 | general roca
# Processing record 14 of set 5 | pucara
# Processing record 15 of set 5 | thinadhoo
# Processing record 16 of set 5 | onda
# Processing record 17 of set 5 | cedral
# Processing record 18 of set 5 | lulea
# Processing record 19 of set 5 | piacabucu
# Processing record 20 of set 5 | kefalos
# Processing record 21 of set 5 | zhangjiakou
# Processing record 22 of set 5 | malangwa
# Processing record 23 of set 5 | merauke
# Processing record 24 of set 5 | saint simons
# Processing record 25 of set 5 | senj
# Processing record 26 of set 5 | bonavista
# Processing record 27 of set 5 | quesnel
# Processing record 28 of set 5 | ilulissat
# Processing record 29 of set 5 | quelimane
# Processing record 30 of set 5 | college
# Processing record 31 of set 5 | westport
# Processing record 32 of set 5 | kupang
# Processing record 33 of set 5 | khash
# Processing record 34 of set 5 | grand river south east
# City not found...
# Processing record 35 of set 5 | nouadhibou
# Processing record 36 of set 5 | san cristobal
# Processing record 37 of set 5 | san rafael
# Processing record 38 of set 5 | puerto madero
# Processing record 39 of set 5 | maningrida
# Processing record 40 of set 5 | mergui
# City not found...
# Processing record 41 of set 5 | mantua
# Processing record 42 of set 5 | ilebo
# Processing record 43 of set 5 | tacna
# Processing record 44 of set 5 | clyde river
# Processing record 45 of set 5 | saint-francois
# Processing record 46 of set 5 | bethel
# Processing record 47 of set 5 | asfi
# Processing record 48 of set 5 | voh
# Processing record 49 of set 5 | salym
# Processing record 50 of set 5 | sao filipe
# Processing record 0 of set 6 | rungata
# City not found...
# Processing record 1 of set 6 | sokoto
# Processing record 2 of set 6 | urfa
# City not found...
# Processing record 3 of set 6 | los llanos de aridane
# Processing record 4 of set 6 | dois riachos
# Processing record 5 of set 6 | conceicao do araguaia
# Processing record 6 of set 6 | kavieng
# Processing record 7 of set 6 | banjar
# Processing record 8 of set 6 | netarhat
# Processing record 9 of set 6 | perene
# Processing record 10 of set 6 | sherlovaya gora
# Processing record 11 of set 6 | tiarei
# Processing record 12 of set 6 | puerto quijarro
# Processing record 13 of set 6 | harper
# Processing record 14 of set 6 | yulara
# Processing record 15 of set 6 | luderitz
# Processing record 16 of set 6 | ahipara
# Processing record 17 of set 6 | shimoda
# Processing record 18 of set 6 | severo-kurilsk
# Processing record 19 of set 6 | paita
# Processing record 20 of set 6 | takoradi
# Processing record 21 of set 6 | mandalgovi
# Processing record 22 of set 6 | egvekinot
# Processing record 23 of set 6 | el alto
# Processing record 24 of set 6 | hajdusamson
# Processing record 25 of set 6 | myitkyina
# Processing record 26 of set 6 | kommunisticheskiy
# Processing record 27 of set 6 | iquitos
# Processing record 28 of set 6 | markova
# Processing record 29 of set 6 | alta gracia
# Processing record 30 of set 6 | kalmunai
# Processing record 31 of set 6 | panjwin
# City not found...
# Processing record 32 of set 6 | asosa
# Processing record 33 of set 6 | hunchun
# Processing record 34 of set 6 | ban pong
# Processing record 35 of set 6 | hervey bay
# Processing record 36 of set 6 | naya bazar
# Processing record 37 of set 6 | kumta
# Processing record 38 of set 6 | aksu
# Processing record 39 of set 6 | norman wells
# Processing record 40 of set 6 | te anau
# Processing record 41 of set 6 | aromashevo
# Processing record 42 of set 6 | margate
# Processing record 43 of set 6 | tual
# Processing record 44 of set 6 | dikson
# Processing record 45 of set 6 | zharkent
# Processing record 46 of set 6 | guerrero negro
# Processing record 47 of set 6 | panjab
# Processing record 48 of set 6 | goderich
# Processing record 49 of set 6 | kaohsiung
# Processing record 50 of set 6 | xiongyue
# Processing record 0 of set 7 | kysyl-syr
# Processing record 1 of set 7 | ixtapa
# Processing record 2 of set 7 | poum
# Processing record 3 of set 7 | portland
# Processing record 4 of set 7 | kurilsk
# Processing record 5 of set 7 | lamu
# Processing record 6 of set 7 | nombre de dios
# Processing record 7 of set 7 | baruun-urt
# Processing record 8 of set 7 | victor harbor
# Processing record 9 of set 7 | sao felix do xingu
# Processing record 10 of set 7 | esperance
# Processing record 11 of set 7 | gorno-chuyskiy
# City not found...
# Processing record 12 of set 7 | lebu
# Processing record 13 of set 7 | mecca
# Processing record 14 of set 7 | lincoln
# Processing record 15 of set 7 | camabatela
# Processing record 16 of set 7 | horsham
# Processing record 17 of set 7 | luanda
# Processing record 18 of set 7 | port macquarie
# Processing record 19 of set 7 | langsa
# Processing record 20 of set 7 | manta
# Processing record 21 of set 7 | puerto ayacucho
# Processing record 22 of set 7 | broome
# Processing record 23 of set 7 | buta
# Processing record 24 of set 7 | slave lake
# Processing record 25 of set 7 | gloucester
# Processing record 26 of set 7 | aguimes
# Processing record 27 of set 7 | pemangkat
# Processing record 28 of set 7 | cayenne
# Processing record 29 of set 7 | hobyo
# Processing record 30 of set 7 | maghama
# City not found...
# Processing record 31 of set 7 | rio grande
# Processing record 32 of set 7 | bembereke
# Processing record 33 of set 7 | gustrow
# Processing record 34 of set 7 | jumla
# Processing record 35 of set 7 | lasa
# Processing record 36 of set 7 | sabibah
# City not found...
# Processing record 37 of set 7 | karratha
# Processing record 38 of set 7 | nicoya
# Processing record 39 of set 7 | bereznik
# Processing record 40 of set 7 | fukuma
# Processing record 41 of set 7 | isangel
# Processing record 42 of set 7 | uglovskoye
# Processing record 43 of set 7 | wanning
# Processing record 44 of set 7 | kirillov
# Processing record 45 of set 7 | jawhar
# Processing record 46 of set 7 | male
# Processing record 47 of set 7 | north battleford
# Processing record 48 of set 7 | nemuro
# Processing record 49 of set 7 | garissa
# Processing record 50 of set 7 | nebolchi
# Processing record 0 of set 8 | tromso
# Processing record 1 of set 8 | darhan
# Processing record 2 of set 8 | portmore
# Processing record 3 of set 8 | nelson bay
# Processing record 4 of set 8 | kavaratti
# Processing record 5 of set 8 | brownfield
# Processing record 6 of set 8 | saint-pierre
# Processing record 7 of set 8 | smithers
# Processing record 8 of set 8 | xuddur
# Processing record 9 of set 8 | marsh harbour
# Processing record 10 of set 8 | zafra
# Processing record 11 of set 8 | natal
# Processing record 12 of set 8 | grand bank
# Processing record 13 of set 8 | san borja
# Processing record 14 of set 8 | sorong
# Processing record 15 of set 8 | isilkul
# Processing record 16 of set 8 | juneau
# Processing record 17 of set 8 | seoul
# Processing record 18 of set 8 | fairbanks
# Processing record 19 of set 8 | havre-saint-pierre
# Processing record 20 of set 8 | ouahigouya
# Processing record 21 of set 8 | bengkulu
# Processing record 22 of set 8 | hirtshals
# Processing record 23 of set 8 | kloulklubed
# Processing record 24 of set 8 | dayong
# Processing record 25 of set 8 | lahaina
# Processing record 26 of set 8 | guarapuava
# Processing record 27 of set 8 | alugan
# Processing record 28 of set 8 | darovskoy
# Processing record 29 of set 8 | olafsvik
# Processing record 30 of set 8 | teloloapan
# Processing record 31 of set 8 | northam
# Processing record 32 of set 8 | bartica
# Processing record 33 of set 8 | port hawkesbury
# Processing record 34 of set 8 | san quintin
# Processing record 35 of set 8 | key west
# Processing record 36 of set 8 | garowe
# Processing record 37 of set 8 | hyeres
# Processing record 38 of set 8 | wanaka
# Processing record 39 of set 8 | gamba
# Processing record 40 of set 8 | hammerfest
# Processing record 41 of set 8 | rundu
# Processing record 42 of set 8 | stoyba
# City not found...
# Processing record 43 of set 8 | alice springs
# Processing record 44 of set 8 | wairoa
# Processing record 45 of set 8 | malakal
# Processing record 46 of set 8 | grindavik
# Processing record 47 of set 8 | manadhoo
# Processing record 48 of set 8 | killarney
# Processing record 49 of set 8 | kigoma
# Processing record 50 of set 8 | omsukchan
# Processing record 0 of set 9 | nabire
# Processing record 1 of set 9 | presidente medici
# Processing record 2 of set 9 | chipinge
# Processing record 3 of set 9 | idritsa
# Processing record 4 of set 9 | yumen
# Processing record 5 of set 9 | komsomolskiy
# Processing record 6 of set 9 | kologriv
# Processing record 7 of set 9 | teguise
# Processing record 8 of set 9 | nizwa
# Processing record 9 of set 9 | saskylakh
# Processing record 10 of set 9 | newport
# Processing record 11 of set 9 | keokuk
# Processing record 12 of set 9 | mrirt
# City not found...
# Processing record 13 of set 9 | tlaxco
# Processing record 14 of set 9 | byron bay
# Processing record 15 of set 9 | sola
# Processing record 16 of set 9 | frankenburg
# Processing record 17 of set 9 | nyagan
# Processing record 18 of set 9 | kyshtovka
# Processing record 19 of set 9 | laguna
# Processing record 20 of set 9 | pagudpud
# Processing record 21 of set 9 | hunza
# City not found...
# Processing record 22 of set 9 | pacific grove
# Processing record 23 of set 9 | ilinskiy
# Processing record 24 of set 9 | atchison
# Processing record 25 of set 9 | tigil
# Processing record 26 of set 9 | otradnoye
# Processing record 27 of set 9 | batman
# Processing record 28 of set 9 | flin flon
# Processing record 29 of set 9 | cradock
# Processing record 30 of set 9 | uk
# City not found...
# Processing record 31 of set 9 | binga
# Processing record 32 of set 9 | assiniboia
# Processing record 33 of set 9 | boyolangu
# Processing record 34 of set 9 | challans
# Processing record 35 of set 9 | zyryanka
# Processing record 36 of set 9 | camocim
# Processing record 37 of set 9 | paredon
# Processing record 38 of set 9 | longjiang
# Processing record 39 of set 9 | harer
# Processing record 40 of set 9 | bandarbeyla
# Processing record 41 of set 9 | coaldale
# Processing record 42 of set 9 | karangasem
# Processing record 43 of set 9 | guanica
# Processing record 44 of set 9 | lensk
# Processing record 45 of set 9 | magadan
# Processing record 46 of set 9 | atambua
# Processing record 47 of set 9 | itaituba
# Processing record 48 of set 9 | manado
# Processing record 49 of set 9 | la paz
# Processing record 50 of set 9 | kamenka
# Processing record 0 of set 10 | maumere
# Processing record 1 of set 10 | azanka
# Processing record 2 of set 10 | avera
# Processing record 3 of set 10 | new milford
# Processing record 4 of set 10 | port hedland
# Processing record 5 of set 10 | requena
# Processing record 6 of set 10 | kijang
# Processing record 7 of set 10 | moree
# Processing record 8 of set 10 | tupik
# Processing record 9 of set 10 | geraldton
# Processing record 10 of set 10 | san miguel
# Processing record 11 of set 10 | cockburn town
# Processing record 12 of set 10 | kamaishi
# Processing record 13 of set 10 | xining
# Processing record 14 of set 10 | yarada
# Processing record 15 of set 10 | mao
# Processing record 16 of set 10 | prince rupert
# Processing record 17 of set 10 | rochefort
# Processing record 18 of set 10 | danjiangkou
# Processing record 19 of set 10 | dom pedrito
# Processing record 20 of set 10 | samarai
# Processing record 21 of set 10 | marigot
# Processing record 22 of set 10 | troitsk
# Processing record 23 of set 10 | hun
# Processing record 24 of set 10 | banes
# Processing record 25 of set 10 | puerto montt
# Processing record 26 of set 10 | mandan
# Processing record 27 of set 10 | redmond
# Processing record 28 of set 10 | vao
# Processing record 29 of set 10 | pitimbu
# Processing record 30 of set 10 | batticaloa
# Processing record 31 of set 10 | lavrentiya
# Processing record 32 of set 10 | wakkanai
# Processing record 33 of set 10 | viedma
# Processing record 34 of set 10 | sitka
# Processing record 35 of set 10 | kidal
# Processing record 36 of set 10 | elban
# Processing record 37 of set 10 | nuuk
# Processing record 38 of set 10 | acarau
# Processing record 39 of set 10 | bumba
# Processing record 40 of set 10 | gospic
# Processing record 41 of set 10 | tiznit
# Processing record 42 of set 10 | vila franca do campo
# Processing record 43 of set 10 | polunochnoye
# Processing record 44 of set 10 | khonuu
# City not found...
# Processing record 45 of set 10 | uchiza
# Processing record 46 of set 10 | reutte
# Processing record 47 of set 10 | nyuksenitsa
# Processing record 48 of set 10 | chapais
# Processing record 49 of set 10 | marystown
# Processing record 50 of set 10 | mbandaka
# Processing record 0 of set 11 | afmadu
# City not found...
# Processing record 1 of set 11 | marsa matruh
# Processing record 2 of set 11 | aykhal
# Processing record 3 of set 11 | marrakesh
# Processing record 4 of set 11 | ewa beach
# Processing record 5 of set 11 | fukue
# Processing record 6 of set 11 | arinos
# Processing record 7 of set 11 | bac lieu
# Processing record 8 of set 11 | paka
# Processing record 9 of set 11 | ouadda
# Processing record 10 of set 11 | yangambi
# Processing record 11 of set 11 | haldibari
# Processing record 12 of set 11 | skegness
# Processing record 13 of set 11 | kokstad
# Processing record 14 of set 11 | marcona
# City not found...
# Processing record 15 of set 11 | puerto suarez
# Processing record 16 of set 11 | washougal
# Processing record 17 of set 11 | fereydunshahr
# Processing record 18 of set 11 | rodrigues alves
# Processing record 19 of set 11 | pali
# Processing record 20 of set 11 | abu kamal
# Processing record 21 of set 11 | grao mogol
# Processing record 22 of set 11 | marawi
# Processing record 23 of set 11 | barra dos coqueiros
# Processing record 24 of set 11 | linxia
# Processing record 25 of set 11 | saint george
# Processing record 26 of set 11 | stary sacz
# Processing record 27 of set 11 | berlevag
# Processing record 28 of set 11 | innisfail
# Processing record 29 of set 11 | shahr-e kord
# Processing record 30 of set 11 | ratnagiri
# Processing record 31 of set 11 | namwala
# Processing record 32 of set 11 | cabedelo
# Processing record 33 of set 11 | korla
# Processing record 34 of set 11 | shamgarh
# Processing record 35 of set 11 | tari
# Processing record 36 of set 11 | santo antonio do ica
# Processing record 37 of set 11 | mongoumba
# Processing record 38 of set 11 | boddam
# Processing record 39 of set 11 | sept-iles
# Processing record 40 of set 11 | mosquera
# Processing record 41 of set 11 | xiangxiang
# Processing record 42 of set 11 | kristiinankaupunki
# Processing record 43 of set 11 | mabai
# Processing record 44 of set 11 | amahai
# Processing record 45 of set 11 | mount gambier
# Processing record 46 of set 11 | omboue
# Processing record 47 of set 11 | bermejo
# Processing record 48 of set 11 | umzimvubu
# City not found...
# Processing record 49 of set 11 | tokur
# Processing record 50 of set 11 | kilindoni
# Processing record 0 of set 12 | glendive
# Processing record 1 of set 12 | udachnyy
# Processing record 2 of set 12 | timizart
# Processing record 3 of set 12 | liwale
# Processing record 4 of set 12 | sobolevo
# Processing record 5 of set 12 | uvira
# Processing record 6 of set 12 | stornoway
# Processing record 7 of set 12 | vallenar
# Processing record 8 of set 12 | ati
# Processing record 9 of set 12 | yakovlevka
# Processing record 10 of set 12 | mahibadhoo
# Processing record 11 of set 12 | maldonado
# Processing record 12 of set 12 | erice
# Processing record 13 of set 12 | motygino
# Processing record 14 of set 12 | russell
# Processing record 15 of set 12 | santa cruz cabralia
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = {"City": new_cities,
                "Cloudiness": cloudiness,
                "Country": country,
                "Date": date,
                "Humidity": humidity,
                "Lat": latitude,
                "Lng": longitude,
                "Max Temp": temp_max,
                "Wind Speed": wind_speed
                }

weather_df = pd.DataFrame(weather_data)
weather_df.count()
# Out:
# City          587
# Cloudiness    587
# Country       587
# Date          587
# Humidity      587
# Lat           587
# Lng           587
# Max Temp      587
# Wind Speed    587
# dtype: int64

# %%
weather_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  plettenberg bay          55      ZA  1588213369        46 -34.05   23.37
# 1     ponta do sol          20      PT  1588213369        72  32.67  -17.10
# 2      new norfolk          97      AU  1588213369        78 -42.78  147.06
# 3            vaini          75      TO  1588213369        74 -21.20 -175.20
# 4     punta arenas         100      CL  1588213135        86 -53.15  -70.92
#
#    Max Temp  Wind Speed
# 0     17.08        2.31
# 1     17.00        2.60
# 2     14.44        0.89
# 3     26.00        6.20
# 4      5.00        2.60

# %%
#CSV file
weather_df.to_csv("cities_weather.csv", encoding="utf-8", index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#scatter plot
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o")
plt.title("Latitude vs. Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# scatter plot
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o")
plt.title("Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# scatter
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CityLatitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# scatter
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o")
plt.title("Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_WindSpeed.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
